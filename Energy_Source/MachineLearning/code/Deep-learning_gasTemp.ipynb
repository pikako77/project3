# 194                           0.004746     63.6      76.4      50.7
# 195                           0.004798     67.1      80.1      54.2
# 196                           0.005392     72.0      85.0      59.0
# 197                           0.006809     80.6      92.3      68.8
# 198                           0.008265     83.6      95.5      71.6
# 199                           0.007597     80.6      91.2      70.1
# 200                           0.005783     76.5      88.4      64.6
# 201                           0.005205     66.5      80.0      53.1
# 202                           0.004474     60.3      73.2      47.4
# 203                           0.005509     47.8      59.7      35.9
# 204                           0.005949     43.9      57.8      29.9
# 205                           0.005088     52.3      64.7      40.0
# 206                           0.005197     61.7      75.0      48.4
# 207                           0.004906     63.0      77.8      48.2
# 208                           0.006775     78.0      90.9      65.2
# 209                           0.007230     83.9      95.8      72.0
# 210                           0.008981     84.5      96.9      72.0
# 211                           0.008276     83.1      95.0      71.1
# 212                           0.006864     76.3      85.7      66.9
# 213                           0.005932     65.4      74.6      56.2
# 214                           0.005231     52.0      63.9      40.1
# 215                           0.005475     48.3      59.2      37.4
# 216                           0.005858     47.2      58.8      35.6
#
#       population
# 0    21274049.67
# 1    21309235.47
# 2    21344421.28
# 3    21379607.09
# 4    21414792.89
# 5    21449978.70
# 6    21485164.50
# 7    21520350.30
# 8    21555536.11
# 9    21590721.92
# 10   21625907.72
# 11   21661093.53
# 12   21696279.33
# 13   21731465.14
# 14   21766650.94
# 15   21801836.75
# 16   21837022.55
# 17   21872208.36
# 18   21907394.17
# 19   21942579.97
# 20   21977765.78
# 21   22012951.58
# 22   22048137.39
# 23   22083323.19
# 24   22118509.00
# 25   22154545.33
# 26   22190581.67
# 27   22226618.00
# 28   22262654.33
# 29   22298690.67
# ..           ...
# 187  28162206.58
# 188  28194308.67
# 189  28226410.75
# 190  28258512.83
# 191  28290614.92
# 192  28322717.00
# 193  28354311.00
# 194  28385905.00
# 195  28417499.00
# 196  28449093.00
# 197  28480687.00
# 198  28512281.00
# 199  28543875.00
# 200  28575469.00
# 201  28607063.00
# 202  28638657.00
# 203  28670251.00
# 204  28701845.00
# 205  28733947.08
# 206  28766049.17
# 207  28798151.25
# 208  28830253.33
# 209  28862355.42
# 210  28894457.50
# 211  28926559.58
# 212  28958661.67
# 213  28990763.75
# 214  29022865.83
# 215  29054967.92
# 216  29087070.00
#
# [217 rows x 11 columns]

# %% [markdown]
# ### Add a decimal month to year

# %%
yr = dataframe["year"]
mo = dataframe["month"].str.lower()

mo[0:13]
# Out:
# 0     jan
# 1     feb
# 2     mar
# 3     apr
# 4     may
# 5     jun
# 6     jul
# 7     aug
# 8     sep
# 9     oct
# 10    nov
# 11    dec
# 12    jan
# Name: month, dtype: object

# %%
step = 1/12
yr_decimal = []

for i in range (len(dataframe)):
    if (mo[i] == 'jan'):
        decinal_mo = 0
    elif (mo[i] == 'feb'):
        decinal_mo = 1
    elif (mo[i] == 'mar'):
        decinal_mo = 2
    elif (mo[i] == 'apr'):
        decinal_mo = 3
    elif (mo[i] == 'may'):
        decinal_mo = 4
    elif (mo[i] == 'jun'):
        decinal_mo = 5
    elif (mo[i] == 'jul'):
        decinal_mo = 6
    elif (mo[i] == 'aug'):
        decinal_mo = 7
    elif (mo[i] == 'sep'):
        decinal_mo = 8
    elif (mo[i] == 'oct'):
        decinal_mo = 9
    elif (mo[i] == 'nov'):
        decinal_mo = 10
    elif (mo[i] == 'dec'):
        decinal_mo = 11
    
    yr_decimal.append(yr[i]+decinal_mo * step)
    
yr_decimal[0:25]
# Out:
# [2001.0,
#  2001.0833333333333,
#  2001.1666666666667,
#  2001.25,
#  2001.3333333333333,
#  2001.4166666666667,
#  2001.5,
#  2001.5833333333333,
#  2001.6666666666667,
#  2001.75,
#  2001.8333333333333,
#  2001.9166666666667,
#  2002.0,
#  2002.0833333333333,
#  2002.1666666666667,
#  2002.25,
#  2002.3333333333333,
#  2002.4166666666667,
#  2002.5,
#  2002.5833333333333,
#  2002.6666666666667,
#  2002.75,
#  2002.8333333333333,
#  2002.9166666666667,
#  2003.0]

# %%
dataframe['yr_decimal'] = yr_decimal
dataframe.head()
# Out:
#    year month      Coal         gas  petroleum  Total_source  \
# 0  2001   Jan  8002.784  147019.775   2583.823    157606.382
# 1  2001   Feb  7220.569  126392.659    486.212    134099.440
# 2  2001   Mar  7610.386  144803.647    257.670    152671.703
# 3  2001   Apr  6900.272  155112.540    139.903    162152.715
# 4  2001   May  8163.586  174142.911     65.535    182372.032
#
#    Total_source_corrected_population  Av_Temp  Max_Temp  Min_Temp  \
# 0                           0.007408     43.9      54.3      33.5
# 1                           0.006293     51.9      63.5      40.4
# 2                           0.007153     53.3      64.0      42.6
# 3                           0.007584     67.8      79.9      55.6
# 4                           0.008516     74.1      86.4      61.8
#
#     population   yr_decimal
# 0  21274049.67  2001.000000
# 1  21309235.47  2001.083333
# 2  21344421.28  2001.166667
# 3  21379607.09  2001.250000
# 4  21414792.89  2001.333333

# %%
dataframe = dataframe.drop(['year', 'month'], axis =1)
dataframe.head()
# Out:
#        Coal         gas  petroleum  Total_source  \
# 0  8002.784  147019.775   2583.823    157606.382
# 1  7220.569  126392.659    486.212    134099.440
# 2  7610.386  144803.647    257.670    152671.703
# 3  6900.272  155112.540    139.903    162152.715
# 4  8163.586  174142.911     65.535    182372.032
#
#    Total_source_corrected_population  Av_Temp  Max_Temp  Min_Temp  \
# 0                           0.007408     43.9      54.3      33.5
# 1                           0.006293     51.9      63.5      40.4
# 2                           0.007153     53.3      64.0      42.6
# 3                           0.007584     67.8      79.9      55.6
# 4                           0.008516     74.1      86.4      61.8
#
#     population   yr_decimal
# 0  21274049.67  2001.000000
# 1  21309235.47  2001.083333
# 2  21344421.28  2001.166667
# 3  21379607.09  2001.250000
# 4  21414792.89  2001.333333

# %%
coal = dataframe['Coal'].values
gas = dataframe['gas'].values
petroleum = dataframe['petroleum'].values
ave_temp =  dataframe['Av_Temp'].values
min_temp =  dataframe['Min_Temp'].values
max_temp =  dataframe['Max_Temp'].values
pop =  dataframe['population'].values
total =  dataframe['Total_source'].values

values = dataframe.values

# %%
groups = [ 0, 1, 2, 3, 4,5 , 6 , 7 , 8]
i = 1

plt.figure()
for group in groups:
	plt.subplot(len(groups), 1, i)
	plt.plot(values[:, group])
	plt.title(dataframe.columns[group], y=0.5, loc='right')
	i += 1
plt.show()

# %%
plt.figure()
plt.scatter(ave_temp , gas)
#plt.scatter(min_temp , gas , label = 'min')
#plt.scatter(max_temp , gas , label = 'max')
plt.xlabel('Temperature')
plt.ylabel('Gas consumption')
# Out:
# Text(0, 0.5, 'Gas consumption')

# %%
plt.figure()
plt.scatter( ave_temp , petroleum, label='Average')
plt.xlabel('Average temperature')
plt.ylabel('petroleum')
plt.legend()

# %%
plt.figure()
plt.scatter( ave_temp , petroleum, label='Average')
plt.xlabel('Temperature')
plt.ylabel('Petroleum consumption')
# Out:
# Text(0, 0.5, 'Petroleum consumption')

# %%
plt.figure()
plt.plot( pop , petroleum, label='Average')
plt.xlabel('Population')
plt.ylabel('Petroleum')
plt.legend()

# %%
plt.figure()
plt.scatter(ave_temp, coal, label='Average')
plt.xlabel('Temperature')
plt.ylabel('Coal consumption')
# Out:
# Text(0, 0.5, 'Coal consumption')

# %%
plt.figure()
plt.scatter(pop, gas, label='Average')

# %%
plt.figure()
plt.scatter(ave_temp, total, label='Average')

# %%
plt.figure()
plt.scatter(ave_temp, total/pop*100, label='Average')
plt.axis((40,90,0.0,1.5))
# Out:
# (40, 90, 0.0, 1.5)

# %% [markdown]
# ### Deep-learning code

# %%
import seaborn as sns
# %matplotlib inline

# calculate the correlation matrix
corr = dataframe.corr()

cmap = 'RdYlGn_r'


# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, 
           cmap= cmap)
plt.yticks(rotation=45) 
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  <a list of 10 Text xticklabel objects>)

# %%
dataframe.head()
# Out:
#        Coal         gas  petroleum  Total_source  \
# 0  8002.784  147019.775   2583.823    157606.382
# 1  7220.569  126392.659    486.212    134099.440
# 2  7610.386  144803.647    257.670    152671.703
# 3  6900.272  155112.540    139.903    162152.715
# 4  8163.586  174142.911     65.535    182372.032
#
#    Total_source_corrected_population  Av_Temp  Max_Temp  Min_Temp  \
# 0                           0.007408     43.9      54.3      33.5
# 1                           0.006293     51.9      63.5      40.4
# 2                           0.007153     53.3      64.0      42.6
# 3                           0.007584     67.8      79.9      55.6
# 4                           0.008516     74.1      86.4      61.8
#
#     population   yr_decimal
# 0  21274049.67  2001.000000
# 1  21309235.47  2001.083333
# 2  21344421.28  2001.166667
# 3  21379607.09  2001.250000
# 4  21414792.89  2001.333333

# %%
dataframe = dataframe.drop(['yr_decimal', 'population', 'petroleum'], axis =1)
dataframe.head()
# Out:
#        Coal         gas  Total_source  Total_source_corrected_population  \
# 0  8002.784  147019.775    157606.382                           0.007408
# 1  7220.569  126392.659    134099.440                           0.006293
# 2  7610.386  144803.647    152671.703                           0.007153
# 3  6900.272  155112.540    162152.715                           0.007584
# 4  8163.586  174142.911    182372.032                           0.008516
#
#    Av_Temp  Max_Temp  Min_Temp
# 0     43.9      54.3      33.5
# 1     51.9      63.5      40.4
# 2     53.3      64.0      42.6
# 3     67.8      79.9      55.6
# 4     74.1      86.4      61.8

# %%
corr = dataframe.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, 
           cmap= cmap)

plt.yticks(rotation=45) 
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  <a list of 7 Text xticklabel objects>)

# %%
dataframe.to_csv('data_for_regression.csv',index=False)

# %%
dataframe = dataframe.drop(['Total_source', 'Total_source_corrected_population', 'Max_Temp','Min_Temp'], axis =1)

# %%
dataframe = dataframe.drop(['Coal'], axis =1)

# %%
X = dataframe.drop("gas", axis=1)
y = dataframe["gas"]
print(X.shape, y.shape)
# Out:
# (217, 1) (217,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(X)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print(rmse)
print(r2)
# Out:
# 12677.602838947065
# 0.8549676069595569

# %%
poly_features = PolynomialFeatures(degree=2)

X_train_poly = poly_features.fit_transform(X_train)
  # fit the transformed features to Linear Regression
poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
  # predicting on training data-set
y_train_predicted = poly_model.predict(X_train_poly)

  # predicting on test data-set
y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))
  
  # evaluating the model on training dataset
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predicted))
r2_train = r2_score(y_train, y_train_predicted)
  
  # evaluating the model on test dataset
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
r2_test = r2_score(y_test, y_test_predict)

# %%
print("The model performance for the training set")
print("-------------------------------------------")
print("RMSE of training set is {}".format(rmse_train))
print("R2 score of training set is {}".format(r2_train))
  
print("\n")
  
print("The model performance for the test set")
print("-------------------------------------------")
print("RMSE of test set is {}".format(rmse_test))
print("R2 score of test set is {}".format(r2_test))
# Out:
# The model performance for the training set
# -------------------------------------------
# RMSE of training set is 12263.367123638722
# R2 score of training set is 0.870993815922903
#
#
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 13631.296711591645
# R2 score of test set is 0.8084739562074397

# %%
x_plot = np.linspace(40, 90, 51)
x_plot = x_plot.reshape(-1, 1)
y_plot = poly_model.predict(poly_features.fit_transform(x_plot))

# %%
plt.figure()
plt.scatter(X, y, color='red',label='Raw data')
plt.plot(x_plot, y_plot, color='blue', linewidth=3, label='Model')
plt.xlabel('Monthly average temperature')
plt.ylabel('Gas consumption')

plt.legend()

# %%
# save the model to disk

pickle.dump(poly_model, open(filename, 'wb'))

# %%
# printing values
print('Slope:' ,poly_model.coef_)
print('Intercept:', poly_model.intercept_)
print()
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [     0.         -13526.82606286    119.19083416]
# Intercept: 513755.9046784076
#
# Root mean squared error:  12677.602838947065
# R2 score:  0.8549676069595569

# %%
coef = poly_model.coef_
intercept = poly_model.intercept_

# %%
# test to get the equation

x_plot = np.linspace(40, 90, 51)
x_plot = x_plot.reshape(-1, 1)
y_plot = coef[1]*x_plot + coef[2]*x_plot*x_plot + intercept#poly_model.predict(poly_features.fit_transform(x_plot))

plt.figure()
plt.scatter(X, y, color='red')
plt.plot(x_plot, y_plot, color='blue', linewidth=3)
plt.xlabel('Monthly average temperature')
plt.ylabel('Gas consumption')
# Out:
# Text(0, 0.5, 'Gas consumption')
