# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
import sklearn.datasets

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import train_test_split
import operator
import pickle

# %%
# load the dataset
filename = 'model/coal_with_allVar.sav' # filename to save model
file = 'data_for_regression.csv'
dataframe = pd.read_csv(file)
dataframe
# Out:
#          Coal         gas  Total_source  Total_source_corrected_population  \
# 0    8002.784  147019.775    157606.382                           0.007408
# 1    7220.569  126392.659    134099.440                           0.006293
# 2    7610.386  144803.647    152671.703                           0.007153
# 3    6900.272  155112.540    162152.715                           0.007584
# 4    8163.586  174142.911    182372.032                           0.008516
# 5    8515.072  192696.004    201243.722                           0.009382
# 6    9325.170  236109.652    245462.592                           0.011425
# 7    9099.212  237944.547    247078.403                           0.011481
# 8    8250.066  181522.560    189790.241                           0.008805
# 9    6828.589  163557.882    170422.254                           0.007893
# 10   7010.164  137883.978    144983.834                           0.006704
# 11   8198.057  138915.012    147146.915                           0.006793
# 12   7881.152  147754.305    155672.579                           0.007175
# 13   7445.423  129186.358    136762.872                           0.006293
# 14   7075.996  145888.783    153163.686                           0.007037
# 15   7188.881  154883.652    162128.967                           0.007436
# 16   8435.380  166769.648    175236.895                           0.008025
# 17   8850.979  197363.891    206247.406                           0.009430
# 18   9173.533  225315.393    234526.251                           0.010705
# 19   9198.243  233057.250    242302.747                           0.011043
# 20   8458.070  188347.159    196850.029                           0.008957
# 21   7784.255  161033.533    168867.104                           0.007671
# 22   7591.186  142892.553    150543.629                           0.006828
# 23   8780.632  136893.259    145741.684                           0.006600
# 24   9453.196  146297.149    155895.437                           0.007048
# 25   7516.398  134239.506    142505.254                           0.006432
# 26   6865.839  138921.068    146196.377                           0.006588
# 27   7629.428  135505.813    143243.988                           0.006445
# 28   8649.123  178066.623    187186.062                           0.008408
# 29   9074.080  179699.177    189407.564                           0.008494
# ..        ...         ...           ...                                ...
# 187  9252.584  215519.692    224787.029                           0.007982
# 188  8901.677  182725.244    191639.880                           0.006797
# 189  8376.552  147810.532    156198.021                           0.005534
# 190  6592.635  131583.915    138191.049                           0.004890
# 191  8728.853  126416.047    135163.910                           0.004778
# 192  8105.948  123126.984    131242.996                           0.004634
# 193  5971.604  109181.755    115165.615                           0.004062
# 194  5809.999  128899.411    134723.698                           0.004746
# 195  6624.876  129717.583    136354.481                           0.004798
# 196  7769.653  145610.379    153399.349                           0.005392
# 197  8744.196  185166.183    193920.099                           0.006809
# 198  9539.478  226095.756    235649.047                           0.008265
# 199  9278.334  207543.187    216839.026                           0.007597
# 200  8495.168  156749.059    165254.848                           0.005783
# 201  7445.180  141429.630    148887.408                           0.005205
# 202  7720.445  120393.267    128128.421                           0.004474
# 203  7982.673  149953.598    157949.440                           0.005509
# 204  7315.907  163398.558    170733.212                           0.005949
# 205  4914.856  141260.871    146184.583                           0.005088
# 206  4236.214  145257.894    149503.716                           0.005197
# 207  4793.495  136464.138    141279.020                           0.004906
# 208  6124.767  189187.177    195329.322                           0.006775
# 209  7057.297  201589.135    208664.049                           0.007230
# 210  7560.935  251921.472    259493.020                           0.008981
# 211  7655.999  231724.319    239389.432                           0.008276
# 212  7042.591  191726.775    198778.924                           0.006864
# 213  6476.976  165499.401    171984.672                           0.005932
# 214  6356.268  145459.215    151830.625                           0.005231
# 215  6363.717  152711.229    159084.876                           0.005475
# 216  5854.458  164538.439    170403.114                           0.005858
#
#      Av Temp  Max Temp  Min Temp
# 0       43.9      54.3      33.5
# 1       51.9      63.5      40.4
# 2       53.3      64.0      42.6
# 3       67.8      79.9      55.6
# 4       74.1      86.4      61.8
# 5       80.9      93.2      68.5
# 6       85.1      97.4      72.7
# 7       82.8      94.7      70.9
# 8       74.9      86.6      63.1
# 9       65.4      79.1      51.7
# 10      58.9      69.9      47.9
# 11      49.4      61.3      37.4
# 12      48.7      61.7      35.7
# 13      47.1      60.6      33.7
# 14      55.4      69.0      41.7
# 15      69.1      80.6      57.5
# 16      74.0      86.5      61.4
# 17      80.6      92.4      68.8
# 18      80.9      91.3      70.6
# 19      82.8      94.7      71.0
# 20      76.0      88.2      63.9
# 21      64.9      74.1      55.6
# 22      53.0      64.9      41.0
# 23      47.8      59.3      36.3
# 24      46.2      58.6      33.7
# 25      48.3      59.3      37.3
# 26      57.2      69.9      44.5
# 27      66.6      80.2      52.9
# 28      75.8      88.2      63.3
# 29      78.5      90.0      66.9
# ..       ...       ...       ...
# 187     81.5      92.2      70.9
# 188     77.6      88.4      66.7
# 189     70.9      84.0      57.7
# 190     61.0      72.5      49.6
# 191     49.6      60.2      38.9
# 192     50.8      63.0      38.6
# 193     58.4      72.0      44.8
# 194     63.6      76.4      50.7
# 195     67.1      80.1      54.2
# 196     72.0      85.0      59.0
# 197     80.6      92.3      68.8
# 198     83.6      95.5      71.6
# 199     80.6      91.2      70.1
# 200     76.5      88.4      64.6
# 201     66.5      80.0      53.1
# 202     60.3      73.2      47.4
# 203     47.8      59.7      35.9
# 204     43.9      57.8      29.9
# 205     52.3      64.7      40.0
# 206     61.7      75.0      48.4
# 207     63.0      77.8      48.2
# 208     78.0      90.9      65.2
# 209     83.9      95.8      72.0
# 210     84.5      96.9      72.0
# 211     83.1      95.0      71.1
# 212     76.3      85.7      66.9
# 213     65.4      74.6      56.2
# 214     52.0      63.9      40.1
# 215     48.3      59.2      37.4
# 216     47.2      58.8      35.6
#
# [217 rows x 7 columns]

# %% [markdown]
# ### Deep-learning code

# %%
import seaborn as sns
# %matplotlib inline

# calculate the correlation matrix
corr = dataframe.corr()

cmap = 'RdYlGn_r'

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, 
           cmap= cmap)

# %%
X = dataframe.drop("Coal", axis=1)
y = dataframe["Coal"]
print(X.shape, y.shape)
# Out:
# (217, 6) (217,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(X)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print(rmse)
print(r2)
# Out:
# 142.95681244514347
# 0.9876661585830409

# %%
poly_features = PolynomialFeatures(degree=2)

X_train_poly = poly_features.fit_transform(X_train)
  # fit the transformed features to Linear Regression
poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
  # predicting on training data-set
y_train_predicted = poly_model.predict(X_train_poly)

  # predicting on test data-set
y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))
  
  # evaluating the model on training dataset
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predicted))
r2_train = r2_score(y_train, y_train_predicted)
  
  # evaluating the model on test dataset
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
r2_test = r2_score(y_test, y_test_predict)

# %%
print("The model performance for the training set")
print("-------------------------------------------")
print("RMSE of training set is {}".format(rmse_train))
print("R2 score of training set is {}".format(r2_train))
  
print("\n")
  
print("The model performance for the test set")
print("-------------------------------------------")
print("RMSE of test set is {}".format(rmse_test))
print("R2 score of test set is {}".format(r2_test))
# Out:
# The model performance for the training set
# -------------------------------------------
# RMSE of training set is 164.31376558736733
# R2 score of training set is 0.9840752540485447
#
#
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 92.09089687865966
# R2 score of test set is 0.994589177782517

# %%
# save the model to disk

pickle.dump(poly_model, open(filename, 'wb'))

# %%
# printing values
print('Slope:' ,poly_model.coef_)
print()
print('Intercept:', poly_model.intercept_)
print()
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [ 3.24910445e+05 -8.57556007e-01  8.51778237e-01  9.09668379e+04
#  -1.11375735e+03  4.39132801e+02  6.73573110e+02  4.21032107e-06
#  -1.23549302e-05  1.37133074e+02  2.82772143e-01 -1.47923127e-01
#  -1.36943603e-01  8.09336535e-06 -1.36018973e+02 -2.54398999e-01
#   1.33481917e-01  1.22887075e-01 -9.84421872e+03 -1.31658701e+05
#   7.80169792e+04  6.17534823e+04  9.57582875e+03 -9.54954943e+03
#  -9.62968713e+03  2.38240434e+03  4.79761436e+03  2.42317195e+03]
#
# Intercept: -322586.9620029209
#
# Root mean squared error:  142.95681244514347
# R2 score:  0.9876661585830409
